# %%
material_id = input("Please enter the material ID1: ")
material_id2 = input("Please enter the material ID2: ")


from mp_api.client import MPRester
with MPRester(api_key = "Vl8EOOGwTctYnDY73f8p8hqq77F47011") as mpr:
    data = mpr.materials.search(material_ids=[material_id, material_id2])
# Out:
# Please enter the material ID1:  mp-149
# Please enter the material ID2:  mp-1
# Retrieving MaterialsDoc documents:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
data[1]
# Out:
# MPDataDoc<MaterialsDoc>(
# builder_meta=EmmetMeta(emmet_version='0.71.0', pymatgen_version='2023.10.4', pull_request=990, database_version='2023.11.1', build_date=datetime.datetime(2023, 10, 18, 21, 30, 3, 258000), license='BY-C'),
# nsites=2,
# elements=[Element Si],
# nelements=1,
# composition=Composition('Si2'),
# composition_reduced=Composition('Si1'),
# formula_pretty='Si',
# formula_anonymous='A',
# chemsys='Si',
# volume=40.32952684741405,
# density=2.312800253345134,
# density_atomic=20.164763423707026,
# symmetry=SymmetryData(crystal_system=<CrystalSystem.cubic: 'Cubic'>, symbol='Fd-3m', number=227, point_group='m-3m', symprec=0.1, version='2.0.2'),
# material_id=MPID(mp-149),
# structure=Structure Summary
# Lattice
#     abc : 3.8492784033699095 3.8492794116013456 3.849278
#  angles : 60.00001213094421 60.00000346645984 60.00001097545789
#  volume : 40.32952684741405
#       A : 3.333573 0.0 1.924639
#       B : 1.111191 3.142924 1.924639
#       C : 0.0 0.0 3.849278
# ...

# %%
example_doc = data[1]

mpid = example_doc.material_id
formula = example_doc.formula_pretty

# %%
mpr.materials.available_fields
# Out:
# ['builder_meta',
#  'nsites',
#  'elements',
#  'nelements',
#  'composition',
#  'composition_reduced',
#  'formula_pretty',
#  'formula_anonymous',
#  'chemsys',
#  'volume',
#  'density',
#  'density_atomic',
#  'symmetry',
#  'material_id',
#  'structure',
#  'deprecated',
#  'deprecation_reasons',
#  'initial_structures',
#  'task_ids',
#  'deprecated_tasks',
#  'calc_types',
#  'last_updated',
#  'created_at',
#  'origins',
#  'warnings',
#  'task_types',
#  'run_types',
#  'entries']

# %%
data7 = mpr.materials.search(material_ids=["mp-136"],fields=["nsites","formula_pretty"])
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data7
# Out:
# [MPDataDoc<MaterialsDoc>(
#  nsites=2,
#  formula_pretty='Fe',
#  fields_not_requested=['builder_meta', 'elements', 'nelements', 'composition', 'composition_reduced', 'formula_anonymous', 'chemsys', 'volume', 'density', 'density_atomic', 'symmetry', 'material_id', 'structure', 'deprecated', 'deprecation_reasons', 'initial_structures', 'task_ids', 'deprecated_tasks', 'calc_types', 'last_updated', 'created_at', 'origins', 'warnings', 'task_types', 'run_types', 'entries']
#  )]

# %%
mpid
# Out:
# MPID(mp-149)

# %%
formula
# Out:
# 'Si'

# %%
with MPRester("Vl8EOOGwTctYnDY73f8p8hqq77F47011") as mpr:
    docs = mpr.summary.search(elements=["Si","O"],band_gap=(0.5, 1.0),fields=["material_id","formula_pretty"])
    #Contains atleast Si and O
    docs3 = mpr.summary.search(chemsys="Si-O",band_gap=(0.5, 1.0),fields=["material_id","formula_pretty"])
    #Conatins exclusively Si and O
# Out:
# /tmp/ipykernel_6720/889988026.py:2: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   docs = mpr.summary.search(elements=["Si","O"],band_gap=(0.5, 1.0),fields=["material_id","formula_pretty"])
# Retrieving SummaryDoc documents:   0%|          | 0/423 [00:00<?, ?it/s]
# /tmp/ipykernel_6720/889988026.py:4: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   docs3 = mpr.summary.search(chemsys="Si-O",band_gap=(0.5, 1.0),fields=["material_id","formula_pretty"])
# Retrieving SummaryDoc documents:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
docs3
# Out:
# [MPDataDoc<SummaryDoc>(
#  formula_pretty='Si2O3',
#  material_id=MPID(mp-1179195),
# ...

# %%
mpr.get_entries_in_chemsys("Si")
# Out:
# Retrieving ThermoDoc documents:   0%|          | 0/42 [00:00<?, ?it/s]
# [mp-1204627-GGA ComputedStructureEntry - Si46         (Si)
#  Energy (Uncorrected)     = -245.1722 eV (-5.3298  eV/atom)
#  Correction               = 0.0000    eV (0.0000   eV/atom)
#  Energy (Final)           = -245.1722 eV (-5.3298  eV/atom)
#  Energy Adjustments:
#    None
#  Parameters:
#    potcar_spec            = [{'titel': 'PAW_PBE Si 05Jan2001', 'hash': 'b2b0ea6feb62e7cde209616683b8f7f5'}]
#    is_hubbard             = False
#    hubbards               = {}
#    run_type               = GGA
#  Data:
#    oxide_type             = None
#    aspherical             = True
#    last_updated           = 2021-02-05 06:54:34.077000
#    task_id                = mp-1846889
#    material_id            = mp-1204627
#    oxidation_states       = {}
#    run_type               = GGA,
#  mp-1244933-GGA ComputedStructureEntry - Si100        (Si)
#  Energy (Uncorrected)     = -507.6027 eV (-5.0760  eV/atom)
# ...

# %%
str = mpr.get_structure_by_material_id("mp-149")
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
str
# Out:
# Structure Summary
# Lattice
#     abc : 3.8492784033699095 3.8492794116013456 3.849278
#  angles : 60.00001213094421 60.00000346645984 60.00001097545789
#  volume : 40.32952684741405
#       A : 3.333573 0.0 1.924639
#       B : 1.111191 3.142924 1.924639
#       C : 0.0 0.0 3.849278
#     pbc : True True True
# PeriodicSite: Si (3.889, 2.75, 6.736) [0.875, 0.875, 0.875]
# PeriodicSite: Si (0.5556, 0.3929, 0.9623) [0.125, 0.125, 0.125]

# %%
from emmet.core.summary import HasProps
docs = mpr.materials.summary.search(
    has_props = [HasProps.dielectric], fields=["material_id"]
)
mpids = [doc.material_id for doc in docs]
#Find all Materials Project IDs for entries with dielectric data
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/7277 [00:00<?, ?it/s]

# %%
mpids
# Out:
# [MPID(mp-28967),
#  MPID(mp-766094),
#  MPID(mp-36577),
#  MPID(mp-1102092),
#  MPID(mp-720391),
#  MPID(mp-4016),
#  MPID(mp-1029799),
#  MPID(mp-3922),
#  MPID(mp-22192),
#  MPID(mp-17389),
#  MPID(mp-37923),
#  MPID(mp-27171),
#  MPID(mp-1205714),
#  MPID(mp-774146),
#  MPID(mp-561153),
#  MPID(mp-7035),
#  MPID(mp-558864),
#  MPID(mp-1029718),
#  MPID(mp-557574),
#  MPID(mp-867113),
#  MPID(mp-510670),
#  MPID(mp-9583),
#  MPID(mp-25971),
#  MPID(mp-552234),
#  MPID(mp-1018100),
#  MPID(mp-7331),
#  MPID(mp-11714),
#  MPID(mp-696125),
#  MPID(mp-22988),
#  MPID(mp-1111927),
#  MPID(mp-754726),
#  MPID(mp-21084),
#  MPID(mp-11607),
#  MPID(mp-763784),
#  MPID(mp-6449),
#  MPID(mp-34116),
#  MPID(mp-613733),
#  MPID(mp-12263),
#  MPID(mp-1190364),
#  MPID(mp-22473),
#  MPID(mp-1023936),
#  MPID(mp-550506),
#  MPID(mp-19970),
#  MPID(mp-752644),
#  MPID(mp-16934),
#  MPID(mp-648932),
#  MPID(mp-4452),
#  MPID(mp-22867),
#  MPID(mp-16945),
#  MPID(mp-556163),
#  MPID(mp-763240),
# ...

# %%
docs2 = mpr.materials.search(material_ids=["mp-149"])
task_ids = docs2[0].calc_types.keys()
task_types = docs2[0].calc_types.values() 
# -- Shortcut for a single Materials Project ID:
task_ids2 = mpr.get_task_ids_associated_with_material_id("mp-149")
#Calculation (task) IDs and types for silicon (mp-149)
# Out:
# ...
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
task_ids2
# Out:
# ['mp-655585',
#  'mp-656511',
#  'mp-655936',
#  'mp-11721',
#  'mp-149',
#  'mp-1057373',
#  'mp-1057366',
#  'mp-1057380',
#  'mp-1059585',
#  'mp-1059589',
#  'mp-1059603',
#  'mp-1120258',
#  'mp-1120259',
#  'mp-1141021',
#  'mp-1248038',
#  'mp-1249516',
#  'mp-1267607',
#  'mp-1440634',
#  'mp-1686587',
#  'mp-1791788',
#  'mp-1594776',
#  'mp-1592727',
#  'mp-1947498',
#  'mp-1950734',
#  'mp-1059604',
#  'mp-1057384',
#  'mp-1536661',
#  'mp-2064724',
#  'mp-2064214',
#  'mp-2250750',
#  'mp-2299819',
#  'mp-2291052',
#  'mp-2693536',
#  'mp-2693792',
#  'mp-2768327',
#  'mp-2683378',
#  'mp-2629357',
#  'mp-2683297',
#  'mp-2629333',
#  'mp-2375783',
#  'mp-2375705',
#  'mp-2375896']

# %%
docs4 = mpr.materials.summary.search(
    chemsys="Si-O", fields=["material_id", "band_gap","formula_pretty"]
)
mpid_bgap_dict = {doc.material_id: doc.band_gap for doc in docs4}
#Band gaps for all materials containing only Si and O
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/343 [00:00<?, ?it/s]

# %%
mpid_bgap_dict
# Out:
# {MPID(mp-1194828): 0.09050000000000002,
#  MPID(mp-1199711): 0.09720000000000018,
#  MPID(mp-1063118): 0.0,
#  MPID(mp-1208867): 0.0,
#  MPID(mp-1179195): 0.9888999999999999,
#  MPID(mp-862998): 2.6763,
#  MPID(mp-32566): 0.09609999999999985,
#  MPID(mp-32881): 0.18850000000000033,
#  MPID(mp-1250755): 0.20499999999999996,
#  MPID(mp-638900): 0.10310000000000041,
#  MPID(mp-1219421): 0.0706,
#  MPID(mp-1221354): 0.030199999999999783,
#  MPID(mp-1179275): 0.0,
#  MPID(mp-1179651): 3.4528,
#  MPID(mp-1173536): 0.08350000000000002,
#  MPID(mp-530027): 2.1050999999999997,
#  MPID(mp-673849): 0.04090000000000005,
#  MPID(mp-731864): 0.008799999999999919,
#  MPID(mp-32761): 0.0,
#  MPID(mp-10064): 1.7395999999999994,
#  MPID(mp-1021503): 4.528499999999999,
#  MPID(mp-1071820): 4.716,
#  MPID(mp-10851): 5.5428,
#  MPID(mp-10948): 5.2394,
#  MPID(mp-11684): 5.5458,
#  MPID(mp-1179447): 5.6304,
#  MPID(mp-1179454): 5.5301,
#  MPID(mp-1179488): 0.14189999999999992,
# ...

# %%
docs5 = mpr.materials.summary.search(
    chemsys="O-*-*", formula="ABC3",
    fields=["material_id","formula_pretty"]
)
mpids = [doc.material_id for doc in docs5]
#Material IDs for all ternary oxides with the form ABC3
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/2606 [00:00<?, ?it/s]

# %%
mpids
# Out:
# [MPID(mp-1069296),
#  MPID(mp-1094112),
#  MPID(mp-1183521),
#  MPID(mp-985586),
#  MPID(mp-28166),
#  MPID(mp-1206996),
#  MPID(mp-753525),
#  MPID(mp-766847),
#  MPID(mp-27277),
#  MPID(mp-772199),
#  MPID(mp-764274),
#  MPID(mp-558934),
#  MPID(mp-675156),
#  MPID(mp-754919),
#  MPID(mp-22938),
#  MPID(mp-1223812),
#  MPID(mp-546285),
#  MPID(mp-1221539),
#  MPID(mp-30950),
#  MPID(mp-673798),
#  MPID(mp-850876),
#  MPID(mp-757111),
#  MPID(mp-776474),
#  MPID(mp-2015815),
#  MPID(mp-753455),
#  MPID(mp-23528),
#  MPID(mp-626534),
#  MPID(mp-625521),
#  MPID(mp-754892),
#  MPID(mp-559377),
#  MPID(mp-761177),
#  MPID(mp-9200),
#  MPID(mp-760414),
#  MPID(mp-28171),
#  MPID(mp-540540),
#  MPID(mp-760313),
#  MPID(mp-760178),
#  MPID(mp-756077),
#  MPID(mp-20273),
#  MPID(mp-27815),
#  MPID(mp-1189731),
#  MPID(mp-754940),
#  MPID(mp-1206444),
#  MPID(mp-34078),
#  MPID(mp-753785),
#  MPID(mp-1208583),
#  MPID(mp-761759),
#  MPID(mp-7961),
#  MPID(mp-753611),
#  MPID(mp-28573),
# ...

# %%
docs6 = mpr.materials.summary.search(
    band_gap=(3, None), is_stable=True, fields=["material_id","formula_pretty"]
)
stable_mpids1 = [doc.material_id for doc in docs6]
    
## -- Alternative directly using energy above hull:
#docs7 = mpr.materials.summary.search(
#    band_gap=(3, None), energy_above_hull=(0, 0), fields=["material_id","formula_pretty"]
#)
#stable_mpids2 = [doc.material_id for doc in docs7]
#Stable materials (on the GGA/GGA+U hull) with large band gaps (>3eV)
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/6092 [00:00<?, ?it/s]

# %%
docs6
# Out:
# [MPDataDoc<SummaryDoc>(
#  formula_pretty='Ac2O3',
#  material_id=MPID(mp-11107),
# ...

# %%
stable_mpids1
# Out:
# [MPID(mp-11107),
#  MPID(mp-1183115),
#  MPID(mp-27972),
#  MPID(mp-30274),
#  MPID(mp-27971),
#  MPID(mp-30273),
#  MPID(mp-985278),
#  MPID(mp-36526),
#  MPID(mp-554873),
#  MPID(mp-703539),
#  MPID(mp-12021),
#  MPID(mp-24058),
#  MPID(mp-24072),
#  MPID(mp-34418),
#  MPID(mp-569787),
#  MPID(mp-555903),
#  MPID(mp-1019377),
#  MPID(mp-758571),
#  MPID(mp-19521),
#  MPID(mp-4417),
#  MPID(mp-756970),
#  MPID(mp-572634),
#  MPID(mp-1199198),
#  MPID(mp-28361),
#  MPID(mp-561437),
#  MPID(mp-707424),
#  MPID(mp-850293),
#  MPID(mp-1196041),
#  MPID(mp-37614),
#  MPID(mp-1143),
#  MPID(mp-23995),
#  MPID(mp-14941),
#  MPID(mp-21892),
#  MPID(mp-1228491),
#  MPID(mp-6280),
#  MPID(mp-1195073),
#  MPID(mp-706243),
#  MPID(mp-5065),
#  MPID(mp-560633),
#  MPID(mp-2908),
#  MPID(mp-31408),
#  MPID(mp-13703),
#  MPID(mp-1190488),
#  MPID(mp-1204107),
#  MPID(mp-3281),
#  MPID(mp-6738),
#  MPID(mp-5189),
#  MPID(mp-672273),
#  MPID(mp-23288),
#  MPID(mp-1214833),
#  MPID(mp-25469),
# ...

# %%
#Band structures for silicon (mp-149)
from emmet.core.electronic_structure import BSPathType
# -- line-mode, Setyawan-Curtarolo (default):
bs_sc = mpr.get_bandstructure_by_material_id("mp-149")
    
# -- line-mode, Hinuma et al.:
bs_hin = mpr.get_bandstructure_by_material_id("mp-149", path_type=BSPathType.hinuma)

# -- line-mode, Latimer-Munro:
bs_hin = mpr.get_bandstructure_by_material_id("mp-149", path_type=BSPathType.latimer_munro)
    
# -- uniform:
bs_uniform = mpr.get_bandstructure_by_material_id("mp-149", line_mode=False)
# Out:
# ...
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
bs_hin
#Learn how to plot them

# %%
#Density of states for silicon (mp-149)

dos = mpr.get_dos_by_material_id("mp-149")
# Out:
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dos

# %%
#XAS(X-ray absorption spectroscopy) for TiO2 element O K edge: 
from emmet.core.xas import Edge, XASDoc, Type
xas = mpr.materials.xas.search(formula = "TiO2", 
                                absorbing_element = 'Ti', 
                                edge = Edge.K)
# Out:
# Retrieving XASDoc documents:   0%|          | 0/99 [00:00<?, ?it/s]

# %%
xas
# Out:
# [MPDataDoc<XASDoc>(
#  nsites=36,
#  elements=[Element O, Element Ti],
#  nelements=2,
#  composition=Composition('Ti12 O24'),
#  composition_reduced=Composition('Ti1 O2'),
#  formula_pretty='TiO2',
#  formula_anonymous='AB2',
#  chemsys='O-Ti',
#  volume=460.72488594034485,
#  density=3.4542161600014927,
#  symmetry=SymmetryData(crystal_system=<CrystalSystem.trig: 'Trigonal'>, symbol='P3m1', number=156, point_group='3m', symprec=0.1, version=None),
#  material_id=MPID(mp-1044853),
#  spectrum_id='mp-1044853-XANES-Ti-K',
#  last_updated=datetime.datetime(2019, 6, 4, 22, 23, 35, 939000),
#  spectrum=Ti K Edge XANES for TiO2: <super: <class 'XAS'>, <XAS object>>,
#  absorbing_element=Element Ti,
#  spectrum_type=<Type.XANES: 'XANES'>,
#  edge=<Edge.K: 'K'>,
#  fields_not_requested=['builder_meta', 'density_atomic', 'spectrum_name', 'warnings', 'task_ids']
#  ),
#  MPDataDoc<XASDoc>(
#  nsites=36,
#  elements=[Element O, Element Ti],
#  nelements=2,
# ...

# %%
#Charge density for silicon (mp-149)
chgcar = mpr.get_charge_density_from_material_id("mp-149")
# Out:
# ...
# Retrieving TaskDoc documents:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
chgcar

# %%
#Phase diagram for the Li-Fe-O chemical system
from emmet.core.thermo import ThermoType
# -- GGA/GGA+U/R2SCAN mixed phase diagram
pd1 = mpr.materials.thermo.get_phase_diagram_from_chemsys(chemsys="Li-Fe-O", 
                                                thermo_type=ThermoType.GGA_GGA_U_R2SCAN)
    
# -- GGA/GGA+U mixed phase diagram
pd2 = mpr.materials.thermo.get_phase_diagram_from_chemsys(chemsys="Li-Fe-O", 
                                                thermo_type=ThermoType.GGA_GGA_U)
                                                   
# -- R2SCAN only phase diagram
pd3 = mpr.materials.thermo.get_phase_diagram_from_chemsys(chemsys="Li-Fe-O", 
                                                thermo_type=ThermoType.R2SCAN)
# Out:
# ...
# Retrieving ThermoDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pd1
# Out:
# Li-Fe-O phase diagram
# 12 stable phases:
# Li, LiO8, FeO, Fe, Fe3O4, Li5FeO4, Li2O, Fe2O3, O2, LiFeO2, Li2FeO3, Li2O2

# %%
pd2
# Out:
# Li-Fe-O phase diagram
# 12 stable phases:
# Li, LiO8, FeO, Fe, Fe3O4, Li5FeO4, Li2O, Fe2O3, O2, LiFeO2, Li2FeO3, Li2O2

# %%
pd3
# Out:
# Li-Fe-O phase diagram
# 11 stable phases:
# Li, Fe, Li2FeO3, Fe3O4, Li5FeO4, Li2O, Fe2O3, O2, LiFeO2, Li2O2, Li3FeO4
